# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("/Users/jcbecker/Documents/GitHub/VPlanet_Senior_Thesis/Radius_Try/paramsnew.txt", delimiter="\t")

# %%
data['env_mass_fraction'] = data['env_mass'] / data['planet_mass']

# %%
data
# Out:
#        stellar_mass  orb_period  planet_mass  env_mass  env_mass_fraction
# 0          1.010000  -18.604190    -7.550928 -2.200406           0.291409
# 1          0.580000  -10.287629    -4.330776 -0.493196           0.113882
# 2          0.930000  -34.179560    -6.300749 -1.352178           0.214606
# 3          0.400000  -43.982310    -6.140916 -1.281534           0.208688
# 4          1.120000  -23.967421    -5.280496 -0.847969           0.160585
# ...             ...         ...          ...       ...                ...
# 17778      1.194300  -19.937257    -1.164280 -0.014321           0.012300
# 17779      0.697435  -42.797965    -1.260646 -0.017747           0.014077
# 17780      1.366892  -30.428121    -2.320050 -0.090621           0.039060
# 17781      1.231492  -29.063169    -1.270381 -0.017965           0.014141
# 17782      1.000000  -30.000000    -1.000000 -0.100000           0.100000
#
# [17783 rows x 5 columns]

# %%
res = plt.hist(data['env_mass_fraction'], bins = 50)

# %%
data = pd.read_csv("/Users/jcbecker/Documents/GitHub/VPlanet_Senior_Thesis/Radius_Try/paramsnew.txt", delimiter="\t")
plt.plot(data['orb_period'], data['env_mass'],'.')

# %%
massarray = np.linspace(0.01, 10)
plt.plot(massarray, 0.1* (massarray / 4.0)**1.7)
