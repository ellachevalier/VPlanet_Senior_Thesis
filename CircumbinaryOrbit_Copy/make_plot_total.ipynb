# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dirs = []
for file in os.listdir("data_working/"):
    d = os.path.join("data_working/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii_binary=[]
initial_radii=[]
good_radii_binary=[]
lens = []
#bad_indices=[]
plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/kepler16_2.cbp.forward'):
        forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii_binary.append(radius.tolist()[-1])
        initial_radii.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii_binary.append(radius.tolist()[-1])
#         else:
#             bad_indices.append(indices[count])
        plt.plot(time, radius)
        count += 1
plt.ylabel("Planet radius (R_earth)")
plt.xlabel("Time (years)")
plt.title("Radius over time with atmospheric escape")
plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
dirs = []
for file in os.listdir("data_working_3000_bin_sep_2/"):
    d = os.path.join("data_working_3000_bin_sep_2/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii_binary=[]
initial_radii=[]
good_radii_binary=[]
lens = []
#bad_indices=[]
plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/kepler16_2.cbp.forward'):
        forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii_binary.append(radius.tolist()[-1])
        initial_radii.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii_binary.append(radius.tolist()[-1])
#         else:
#             bad_indices.append(indices[count])
        #plt.plot(time, radius)
        count += 1
plt.ylabel("Planet radius (R_earth)")
plt.xlabel("Time (years)")
plt.title("Radius over time with atmospheric escape")
plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
len(good_radii_binary)
# Out:
# 241

# %%
dirs = []
for file in os.listdir("data_working_3000/"):
    d = os.path.join("data_working_3000/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii_binary=[]
initial_radii_binary=[]
good_initial_radii_binary=[]
good_radii_binary=[]


lens = []
#bad_indices=[]
plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/kepler16_2.cbp.forward'):
        forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii_binary.append(radius.tolist()[-1])
        initial_radii_binary.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii_binary.append(radius.tolist()[-1])
            good_initial_radii_binary.append(radius.tolist()[0])
#         else:
#             bad_indices.append(indices[count])
        #plt.plot(time, radius)
        count += 1
plt.ylabel("Planet radius (R_earth)")
plt.xlabel("Time (years)")
plt.title("Radius over time with atmospheric escape")
plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
plt.figure()

plt.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='skyblue', label="Final Radii") #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
plt.hist(good_initial_radii_binary, bins=100, color="lightgrey", label="Initial Radii")
plt.xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend()
plt.xlim(0,15)
plt.title("Radius Distribution for Binary Stars")
plt.tick_params(axis='x', labelsize=15)
# Show the plot
#plt.show()
plt.savefig('binary_histogram_initial.png', dpi=300)

# %%
len(good_radii_binary)
# Out:
# 659

# %%
dirs = []
for file in os.listdir("../Radius_Try/data_working_3000/"):
    d = os.path.join("../Radius_Try/data_working_3000/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii=[]
initial_radii=[]
good_initial_radii=[]
good_radii=[]
lens = []
#bad_indices=[]
#plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/system3.planet.forward'):
        forward_file = os.path.join(path, 'system3.planet.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii.append(radius.tolist()[-1])
        initial_radii.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii.append(radius.tolist()[-1])
            good_initial_radii.append(radius.tolist()[0])
#         else:
#             bad_indices.append(indices[count])
        #plt.plot(time, radius)
        count += 1
# plt.ylabel("Planet radius (R_earth)")
# plt.xlabel("Time (years)")
# plt.title("Radius over time with atmospheric escape")
# plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii, bins=50, color='skyblue') #orb period 20, planet mass loc=3, scale=10, size=size

plt.hist(good_initial_radii, bins=100, color="pink")
plt.hist(initial_radii, bins=100, color="grey")
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
import matplotlib.patches as patches

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 4), sharey=True)

ax1.hist(good_radii, bins=50, color='skyblue', edgecolor='skyblue', zorder=2) #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
#ax1.hist(good_initial_radii, bins=100, color="lightgrey", label="Initial Radii")
ax1.set_xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
ax1.set_ylabel('Counts', fontsize=15)
#ax1.set_tick_params(axis='x', labelsize=15)
#ax1.set_xlim(0,15)
#ax1.legend()
rectangle = patches.Rectangle((1.5, 0), 0.5, 200,
                              facecolor='lightgrey', edgecolor='lightgray', linewidth=2, alpha=0.7, zorder=1, label="Observed Radius Gap")

# 4. Add the Rectangle to the Axes
ax1.add_patch(rectangle)
#ax1.legend()

ax1.set_ylim(0,200)
ax1.set_title("Single Star", fontsize=15)

ax2.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='skyblue', zorder=2) #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
#ax2.hist(good_initial_radii_binary, bins=100, color="lightgrey", label="Initial Radii")
ax2.set_xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
#ax2.set_ylabel('Counts', fontsize=15)
#ax2.set_tick_params(axis='x', labelsize=15)
#ax2.set_xlim(0,15)
#ax2.legend()
rectangle = patches.Rectangle((1.5, 0), 0.5, 200,
                              facecolor='lightgrey', edgecolor='lightgray', linewidth=2, alpha=0.7, zorder=1, label="Observed Radius Gap")

# 4. Add the Rectangle to the Axes
ax2.add_patch(rectangle)
ax2.legend()
ax2.set_ylim(0,200)
ax2.set_title("Binary Star", fontsize=15)

plt.tight_layout()
# Show the plot
#plt.show()
plt.savefig('final_histogram_combined.png', dpi=300)

# %%
dirs = []
for file in os.listdir("../Radius_Try/data_working_3000_6_23/"):
    d = os.path.join("../Radius_Try/data_working_3000_6_23/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii2=[]
initial_radii2=[]
good_initial_radii2=[]
good_radii2=[]
lens = []
semi_major_axis_good = []
semi_major_axis_bad = []
orbper_good = []
orbper_bad = []
fxuv_good=[]
fxuv_bad=[]
#bad_indices=[]
#plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/system3.planet.forward'):
        forward_file = os.path.join(path, 'system3.planet.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii2.append(radius.tolist()[-1])
        initial_radii2.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii2.append(radius.tolist()[-1])
            good_initial_radii2.append(radius.tolist()[0])
            semi_major_axis_good.append(df[4].tolist()[0])
            orbper_good.append(df[5].tolist()[0])
            fxuv_good.append(df[6].tolist()[0])
        else:
            semi_major_axis_bad.append(df[4].tolist()[0])
            orbper_bad.append(df[5].tolist()[0])
            fxuv_bad.append(df[6].tolist()[0])
#             bad_indices.append(indices[count])
        #plt.plot(time, radius)
        count += 1
# plt.ylabel("Planet radius (R_earth)")
# plt.xlabel("Time (years)")
# plt.title("Radius over time with atmospheric escape")
# plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii2, bins=50, color='skyblue') #orb period 20, planet mass loc=3, scale=10, size=size

plt.hist(good_initial_radii2, bins=100, color="pink")
plt.hist(initial_radii2, bins=100, color="grey")
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
dirs = []
for file in os.listdir("data_working_3000_6_23/"):
    d = os.path.join("data_working_3000_6_23/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii_binary2=[]
initial_radii_binary2=[]
good_initial_radii_binary2=[]
good_radii_binary2=[]
lens = []
semi_major_axis_binary_good=[]
semi_major_axis_binary_bad=[]
orbper_binary_good=[]
orbper_binary_bad=[]
fxuv_binary_good=[]
fxuv_binary_bad=[]
init_env_mass_good=[]
init_env_mass_bad=[]
#bad_indices=[]
plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/kepler16_2.cbp.forward'):
        forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii_binary2.append(radius.tolist()[-1])
        initial_radii_binary2.append(radius.tolist()[0])
        if len(time)==10001:
            init_env_mass_good.append(env_mass[0])
            good_radii_binary2.append(radius.tolist()[-1])
            good_initial_radii_binary2.append(radius.tolist()[0])
            semi_major_axis_binary_good.append(df[4].tolist()[0])
            orbper_binary_good.append(df[5].tolist()[0])
            fxuv_binary_good.append(df[6].tolist()[0])
        else:
            init_env_mass_bad.append(env_mass[0])
            semi_major_axis_binary_bad.append(df[4].tolist()[0])
            orbper_binary_bad.append(df[5].tolist()[0])
            fxuv_binary_bad.append(df[6].tolist()[0])
#             bad_indices.append(indices[count])
        #plt.plot(time, radius)
        count += 1
plt.ylabel("Planet radius (R_earth)")
plt.xlabel("Time (years)")
plt.title("Radius over time with atmospheric escape")
plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii_binary2, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
import re

dirs = []
for file in os.listdir("data_working_3000_6_23/"):
    d = os.path.join("data_working_3000_6_23/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

env_masses_good=[]
env_masses_bad=[]
for path in sorted_dirs:
    if os.path.exists(path+'/cbp.in'):
        with open(txt_file, 'r') as file:
            txt_file = os.path.join(path, 'cbp.in')
            lines = file.readlines()
            line = [line for line in lines if line.startswith('dEnvelopeMass')]
            ans= re.search(r"[-+]?\d*\.\d+", str(line))
        if os.path.exists(path+'/kepler16_2.cbp.forward'):
            forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
            df=pd.read_csv(forward_file, sep=' ', header=None)
            time = df[0]
            if len(time)==10001:
                env_masses_good.append(float(ans.group(0))*-1)
            else:
                env_masses_bad.append(float(ans.group(0))*-1)

# %%
dirs = []
for file in os.listdir("data_working_3000_6_23/"):
    d = os.path.join("data_working_3000_6_23/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

#env_masses_good=[]
env_masses_na=[]
for path in sorted_dirs:
    if os.path.exists(path+'/cbp.in'):
        with open(txt_file, 'r') as file:
            txt_file = os.path.join(path, 'cbp.in')
            lines = file.readlines()
            line = [line for line in lines if line.startswith('dEnvelopeMass')]
            ans= re.search(r"[-+]?\d*\.\d+", str(line))
        if not os.path.exists(path+'/kepler16_2.cbp.forward'):
            env_masses_na.append(float(ans.group(0))*-1)

# %%
env_masses_na
# Out:
# [0.27125105172682246,
#  0.08111611580834291,
#  1.3377594240033963,
#  1.214461721651682,
#  1.2121068633683616,
#  0.17518603171573832,
#  1.145551238566972,
#  1.225325038666563,
#  0.26811702733215276,
#  1.2438915938320607,
#  1.201963464298814,
#  1.1990427534849533,
#  0.2121088032623286,
#  1.2144290306016634,
#  1.1042287774222905,
#  1.1101950294028442,
#  1.0752383276110369,
#  0.24426420646608832,
#  1.299762792446733,
#  0.16753431594307075,
#  0.3124174791922102,
#  0.18844262083220814,
#  1.259270587488956,
#  0.1857444517823703,
#  1.2984820945626947,
#  1.1960465045140958,
#  1.1433988057365354,
#  1.1410080084671566,
#  0.18376694085049544,
#  1.2487711554478835,
#  0.050708523170295394,
#  0.04364716064365644,
#  1.0821152017413,
#  1.0105782663639578,
#  1.172168063903284,
#  1.155297658696467,
#  1.16327332575694,
#  1.101082824760373,
#  1.3269345682518159,
#  0.20972513328751116,
#  1.2261612809548859,
#  0.28621388169784395,
#  0.286739902046754,
# ...

# %%
plt.scatter(semi_major_axis_binary_good, env_masses_good)
plt.scatter(semi_major_axis_binary_bad, env_masses_bad)
#plt.scatter([0.2]*len(env_masses_na), env_masses_na)
plt.xlabel('Semi Major Axis [au]')
plt.ylabel('Envelope Mass [Earth masses]')
# Out:
# Text(0, 0.5, 'Envelope Mass [Earth masses]')

# %%
x=len(semi_major_axis_binary_good)
y=len(semi_major_axis_binary_bad)
x+y
plt.hist(semi_major_axis_binary_bad)
plt.hist(semi_major_axis_binary_good)
# Out:
# (array([ 18.,  78.,  84.,  74.,  88., 105.,  90.,  63.,  42.,  17.]),
#  array([0.063638 , 0.0855919, 0.1075458, 0.1294997, 0.1514536, 0.1734075,
#         0.1953614, 0.2173153, 0.2392692, 0.2612231, 0.283177 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(orbper_binary_bad)
plt.hist(orbper_binary_good)
# Out:
# (array([80., 74., 76., 81., 75., 70., 68., 84., 19., 32.]),
#  array([10.131004 , 15.1229654, 20.1149268, 25.1068882, 30.0988496,
#         35.090811 , 40.0827724, 45.0747338, 50.0666952, 55.0586566,
#         60.050618 ]),
#  <BarContainer object of 10 artists>)

# %%
import re

dirs = []
for file in os.listdir("data_working_3000_6_23/"):
    d = os.path.join("data_working_3000_6_23/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

masses_good=[]
masses_bad=[]
for path in sorted_dirs:
    if os.path.exists(path+'/primary.in'):
        with open(txt_file, 'r') as file:
            txt_file = os.path.join(path, 'primary.in')
            lines = file.readlines()
            line = [line for line in lines if line.startswith('dMass')]
            ans= re.search(r"[-+]?\d*\.\d+", str(line))
        if os.path.exists(path+'/kepler16_2.cbp.forward'):
            forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
            df=pd.read_csv(forward_file, sep=' ', header=None)
            time = df[0]
            if len(time)==10001:
                masses_good.append(float(ans.group(0)))
            else:
                masses_bad.append(float(ans.group(0)))

# %%
plt.hist(masses_bad)
plt.hist(masses_good)
# Out:
# (array([ 21.,  21.,  27.,  57.,  65., 105., 117., 124.,  76.,  46.]),
#  array([0.1157046 , 0.24313414, 0.37056368, 0.49799322, 0.62542276,
#         0.7528523 , 0.88028184, 1.00771138, 1.13514092, 1.26257046,
#         1.39      ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(fxuv_binary_bad)
plt.hist(fxuv_binary_good)
#fxuv_binary_good
# Out:
# (array([236., 182.,  86.,  53.,  33.,  27.,  18.,  12.,   7.,   5.]),
#  array([  5.333988 ,  15.9116818,  26.4893756,  37.0670694,  47.6447632,
#          58.222457 ,  68.8001508,  79.3778446,  89.9555384, 100.5332322,
#         111.110926 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, axs = plt.subplots(2, 2)

# Plot on the individual subplots using their array indices
axs[0, 0].hist(semi_major_axis_binary_bad, color='lightcoral', label="Unstable")
axs[0, 0].hist(semi_major_axis_binary_good, color='skyblue', label="Stable")
axs[0, 0].set_title('Semi Major Axis')
axs[0,0].set_ylabel('Counts')
axs[0,0].set_xlabel('Semi Major Axis [au]')


axs[0, 1].hist(orbper_binary_bad, color='lightcoral')
axs[0, 1].hist(orbper_binary_good, color='skyblue')
axs[0, 1].set_title('Orbital Period')
axs[0,1].set_ylabel('Counts')
axs[0,1].set_xlabel('Orbital Period [Days]')

axs[1, 0].hist(masses_bad, color='lightcoral')
axs[1, 0].hist(masses_good, color='skyblue')
axs[1, 0].set_title('Stellar Mass')
axs[1,0].set_ylabel('Counts')
axs[1,0].set_xlabel(r'Stellar Mass [M$_\odot$]')

axs[1, 1].hist(fxuv_binary_bad, color='lightcoral', label="Unstable")
axs[1, 1].hist(fxuv_binary_good, color='skyblue', label="Stable")
axs[1, 1].set_title('FXUV')
axs[1, 1].legend(fontsize=10)
axs[1,1].set_ylabel('Counts')
axs[1,1].set_xlabel(r'Flux [W/m$^2$]')


# Adjust layout to prevent overlapping titles/labels
plt.tight_layout()
plt.savefig('comparing_unstable_stable.png', dpi=300)

# %%
line = [line for line in lines if line.startswith('dMass')]
line
ans= re.search(r"[-+]?\d*\.\d+", str(line))
float(ans.group(0))
# Out:
# 1.07

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4), sharey=True)

ax1.hist(good_radii, bins=50, color='skyblue', edgecolor='skyblue', label="Final Radii") #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
ax1.hist(good_initial_radii, bins=100, color="lightgrey", label="Initial Radii")
ax1.set_xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
ax1.set_ylabel('Counts', fontsize=15)
#ax1.set_tick_params(axis='x', labelsize=15)
ax1.set_xlim(0,15)
ax1.legend()
ax1.set_title("Single Star", fontsize=15)

ax2.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='skyblue', label="Final Radii") #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
ax2.hist(good_initial_radii_binary, bins=100, color="lightgrey", label="Initial Radii")
ax2.set_xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
#ax2.set_ylabel('Counts', fontsize=15)
#ax2.set_tick_params(axis='x', labelsize=15)
ax2.set_xlim(0,15)
#ax2.legend()
ax2.set_title("Binary Star", fontsize=15)

plt.tight_layout()
# Show the plot
#plt.show()
#plt.savefig('single_histogram.png', dpi=300)

# %%
semi_major_axis
# Out:
# [0.209194,
#  0.247159,
#  0.262544,
#  0.181176,
#  0.10269,
#  0.164198,
#  0.198976,
#  0.15273,
#  0.121162,
#  0.179588,
#  0.178331,
#  0.16189,
#  0.187683,
#  0.08594,
#  0.257462,
#  0.207986,
#  0.158211,
#  0.309482,
#  0.170842,
#  0.197833,
#  0.108461,
#  0.15135,
#  0.266091,
#  0.114824,
#  0.16055,
#  0.245623,
#  0.19394,
#  0.263634,
#  0.130953,
#  0.212127,
#  0.17528,
#  0.216036,
#  0.115159,
#  0.277547,
#  0.131224,
#  0.206753,
#  0.160687,
#  0.194037,
#  0.094321,
#  0.126459,
#  0.246799,
#  0.231483,
#  0.118733,
#  0.155749,
#  0.171252,
#  0.127774,
#  0.223017,
#  0.224416,
#  0.288316,
#  0.216226,
#  0.176946,
#  0.223624,
#  0.170071,
#  0.275454,
#  0.110261,
#  0.135891,
#  0.232528,
#  0.198927,
#  0.252851,
#  0.20922,
#  0.185569,
#  0.146972,
#  0.296183,
#  0.112329,
#  0.16884,
#  0.105525,
#  0.271406,
#  0.207654,
#  0.163002,
#  0.114084,
#  0.097907,
#  0.254944,
#  0.263162,
#  0.138398,
#  0.097295,
#  0.114509,
#  0.147587,
# ...

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(10, 3), sharex=True)

ax1.hist(good_radii, bins=50, color='skyblue', edgecolor='skyblue', label="Final Radii") #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
ax1.hist(good_initial_radii, bins=100, color="lightgrey", label="Initial Radii")
#ax1.set_xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
ax1.set_ylabel('Counts', fontsize=15)
#ax1.set_tick_params(axis='x', labelsize=15)
ax1.set_xlim(0,15)
ax1.legend()
ax1.set_title("Single Star", fontsize=15)

ax2.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='skyblue', label="Final Radii") #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
ax2.hist(good_initial_radii_binary, bins=100, color="lightgrey", label="Initial Radii")
ax2.set_xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
ax2.set_ylabel('Counts', fontsize=15)
#ax2.set_tick_params(axis='x', labelsize=15)
ax2.set_xlim(0,15)
#ax2.legend()
ax2.set_title("Binary Star", fontsize=15)


# Show the plot
#plt.show()
#plt.savefig('single_histogram.png', dpi=300)
# Out:
# Text(0.5, 1.0, 'Binary Star')

# %%
plt.figure()

plt.hist(good_radii, bins=50, color='skyblue', edgecolor='skyblue', label="Final Radii") #orb period 20, planet mass loc=3, scale=10, size=size
#plt.title('Good Distribution of Planet Radii')
plt.hist(good_initial_radii, bins=100, color="lightgrey", label="Initial Radii")
plt.xlabel('Radius '+r'[$R_\oplus$]', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend()
plt.xlim(0,15)
plt.title("Radius Distribution for Single Stars")
plt.tick_params(axis='x', labelsize=15)
# Show the plot
#plt.show()
plt.savefig('single_histogram_initial.png', dpi=300)

# %%
len(good_radii)
#good_radii_short = np.random.choice(good_radii, size=659)
# Out:
# 2869

# %%
len(good_radii_binary)
# Out:
# 659

# %%
import numpy as np
from scipy import stats

# %%
stat, p = stats.kstest(good_radii, good_radii_binary)
print(stat, p)
# Out:
# 0.28932585309659903 4.1213923659396e-40

# %%
stat, p = stats.kstest([1,1,1], [1,1,1])
print(stat, p)
# Out:
# 0.0 1.0

# %%
plt.figure()
plt.hist(good_radii, bins=50, color='teal', edgecolor='black', alpha=0.5, label='Single Star')
plt.hist(good_radii_binary, bins=50, color='red', edgecolor='black', alpha=0.5, label='Binary Star')
plt.legend(fontsize=12)
plt.xlabel('Radius '+r'[$R_{\oplus}$]', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.tick_params(axis='x', labelsize=15)
plt.savefig('both_histogram.png', dpi=300)
#plt.show()

# %%
n1 = len(good_radii)
n2 = len(good_radii_binary)
eff_size = stat * np.sqrt(n1*n2/(n1+n2))
eff_size
# Out:
# 1.526525026311647

# %%
n=(1.36+1.07)**2 / eff_size**2
n
# Out:
# 2.5339887935325396

# %%
def ks_sample_size(alpha=0.05, power=0.8, effect_size=eff_size):
    """
    Estimates the required sample size for a two-sample Kolmogorov-Smirnov test.
    
    Parameters:
    alpha (float): Significance level (Type I error rate)
    power (float): Desired power (1 - Type II error rate)
    effect_size (float): Expected KS effect size (difference in distributions)
    
    Returns:
    int: Estimated required sample size per group.
    """
    # Compute critical values
    c_alpha = np.sqrt(-0.5 * np.log(alpha / 2))
    c_beta = np.sqrt(-0.5 * np.log(1 - power))
    
    # Compute required sample size per group
    n = ((c_alpha + c_beta) / effect_size) ** 2
    
    return int(np.ceil(n))

# Example usage
effect_size = 0.2  # Typical values: 0.1 (small), 0.2 (medium), 0.3+ (large)
n_required = ks_sample_size(alpha=0.05, power=0.8, effect_size=effect_size)
print(f"Estimated required sample size per group: {n_required}")
# Out:
# Estimated required sample size per group: 128

# %%
dirs = []
for file in os.listdir("data_trial_2/"):
    d = os.path.join("data_trial_2/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii_binary=[]
initial_radii=[]
good_radii_binary=[]
lens = []
#bad_indices=[]
plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/kepler16_2.cbp.forward'):
        forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii_binary.append(radius.tolist()[-1])
        initial_radii.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii_binary.append(radius.tolist()[-1])
#         else:
#             bad_indices.append(indices[count])
        plt.plot(time, radius)
        count += 1
plt.ylabel("Planet radius (R_earth)")
plt.xlabel("Time (years)")
plt.title("Radius over time with atmospheric escape")
plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
len(good_radii_binary)
# Out:
# 14

# %%
dirs = []
for file in os.listdir("data_trial_3/"):
    d = os.path.join("data_trial_3/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii_binary=[]
initial_radii=[]
good_radii_binary=[]
lens = []
#bad_indices=[]
plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/kepler16_2.cbp.forward'):
        forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii_binary.append(radius.tolist()[-1])
        initial_radii.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii_binary.append(radius.tolist()[-1])
#         else:
#             bad_indices.append(indices[count])
        plt.plot(time, radius)
        count += 1
plt.ylabel("Planet radius (R_earth)")
plt.xlabel("Time (years)")
plt.title("Radius over time with atmospheric escape")
plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
len(good_radii_binary)
# Out:
# 130

# %%
dirs = []
for file in os.listdir("data_trial_4/"):
    d = os.path.join("data_trial_4/", file)
    if os.path.isdir(d):
        dirs.append(d)
        
sorted_dirs = sorted(dirs)
sorted_dirs

final_radii_binary=[]
initial_radii=[]
good_radii_binary=[]
lens = []
#bad_indices=[]
plt.figure() 
count = 0
for path in sorted_dirs:
    if os.path.exists(path+'/kepler16_2.cbp.forward'):
        forward_file = os.path.join(path, 'kepler16_2.cbp.forward')
        df=pd.read_csv(forward_file, sep=' ', header=None)
        time = df[0]
        lens.append(len(time))
        mass = df[1]
        env_mass = df[2]
        radius = df[3]
        final_radii_binary.append(radius.tolist()[-1])
        initial_radii.append(radius.tolist()[0])
        if len(time)==10001:
            good_radii_binary.append(radius.tolist()[-1])
#         else:
#             bad_indices.append(indices[count])
        plt.plot(time, radius)
        count += 1
plt.ylabel("Planet radius (R_earth)")
plt.xlabel("Time (years)")
plt.title("Radius over time with atmospheric escape")
plt.show()

# plt.figure()

# plt.hist(final_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
# plt.title('Final Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

# plt.figure()
# plt.hist(initial_radii, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size

# #plt.xlim(0,4)
# # Add titles and labels
# plt.title('Initial Distribution of Planet Radii')
# plt.xlabel('Radius [R_earth]')
# plt.ylabel('Frequency')

plt.figure()

plt.hist(good_radii_binary, bins=50, color='skyblue', edgecolor='black') #orb period 20, planet mass loc=3, scale=10, size=size
plt.title('Good Distribution of Planet Radii')
plt.xlabel('Radius [R_earth]')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
len(good_radii_binary)
# Out:
# 348

# %%
stat, p = stats.kstest(good_radii, good_radii_binary)
print(stat, p)
# Out:
# 0.13685057471264367 0.0008051431300020223

# %%
plt.figure()
plt.hist(good_radii, bins=50, color='red', edgecolor='black', alpha=0.5, label='single star')
plt.hist(good_radii_binary, bins=50, color='teal', edgecolor='black', alpha=0.5, label='binary star')
plt.legend()
plt.xlabel('Radius '+r'($R_{\oplus}$)')
plt.ylabel('Count')
plt.show()
